# %%
pip install --upgrade audiofeatures
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from audiofeatures import extract_features

df = extract_features("/Users/dhyan/Desktop/project/audio_emotion/data/DEAM_audio/MEMD_audio/2029.mp3")

print(df.head())
# Out:
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
#    window  start_time  end_time       rms       zcr      energy  \
# 0       0         0.0       0.5  0.174975 -0.881814  337.543915
# 1       1         0.5       1.0  0.164385 -0.875737  297.921967
# 2       2         1.0       1.5  0.199982 -0.906757  440.922607
# 3       3         1.5       2.0  0.163005 -0.919909  292.942932
# 4       4         2.0       2.5  0.118389 -0.948662  154.526489
#
#    peak_amplitude  crest_factor  dynamic_range  energy_variability  ...  \
# 0        0.688580      3.935305       1.324150            0.007810  ...
# 1        0.735711      4.475535       1.304316            0.008052  ...
# 2        0.965982      4.830335       1.684835            0.014934  ...
# 3        0.558363      3.425425       1.043274            0.002669  ...
# ...

# %%
df
# Out:
#      window  start_time  end_time       rms       zcr      energy  \
# 0         0         0.0       0.5  0.174975 -0.881814  337.543915
# 1         1         0.5       1.0  0.164385 -0.875737  297.921967
# 2         2         1.0       1.5  0.199982 -0.906757  440.922607
# 3         3         1.5       2.0  0.163005 -0.919909  292.942932
# 4         4         2.0       2.5  0.118389 -0.948662  154.526489
# ..      ...         ...       ...       ...       ...         ...
# 332     332       166.0     166.5  0.184449 -0.911293  375.084869
# 333     333       166.5     167.0  0.153527 -0.915283  259.866302
# 334     334       167.0     167.5  0.167818 -0.916735  310.497040
# 335     335       167.5     168.0  0.052390 -0.937868   30.260244
# 336     336       168.0     168.5  0.032140 -0.967891   11.388441
#
#      peak_amplitude  crest_factor  dynamic_range  energy_variability  ...  \
# 0          0.688580      3.935305       1.324150            0.007810  ...
# ...

# %%
from audiofeatures import extract_dataset

df = extract_dataset(
    dataset_path="/Users/dhyan/Desktop/project/test data",
    output_csv="/Users/dhyan/Desktop/project/test data"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from audiofeatures import extract_dataset
# ----> 3 df = extract_dataset(
#       4     dataset_path="/Users/dhyan/Desktop/project/test data",
#       5     output_csv="/Users/dhyan/Desktop/project/test data"
#       6 )
#
# TypeError: extract_dataset() got an unexpected keyword argument 'dataset_path'

# %%
from audiofeatures import extract_dataset

print(extract_dataset)
# Out:
# <function extract_dataset at 0x104418400>

# %%
pip install audiofeatures==2.3.0
# Out:
# ERROR: Could not find a version that satisfies the requirement audiofeatures==2.3.0 (from versions: 0.1.0, 0.1.2, 0.1.5, 0.1.6, 2.2.0)
# ERROR: No matching distribution found for audiofeatures==2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m pip install --upgrade audiofeatures
# Out:
#   Cell In[2], line 1
#     python -m pip install --upgrade audiofeatures
#               ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade audiofeatures
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import audiofeatures

print(audiofeatures.__file__)
# Out:
# /Users/dhyan/Desktop/project/audio_emotion/project/pypi-audiofeatures/audiofeatures/__init__.py

# %%
import importlib.metadata

print(importlib.metadata.version("audiofeatures"))
# Out:
# 2.3.0

# %%
from audiofeatures import extract_dataset

df = extract_dataset(
    dataset_path="/Users/dhyan/Desktop/project/test data",
    output_csv="/Users/dhyan/Desktop/project/test data"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from audiofeatures import extract_dataset
# ----> 3 df = extract_dataset(
#       4     dataset_path="/Users/dhyan/Desktop/project/test data",
#       5     output_csv="/Users/dhyan/Desktop/project/test data"
#       6 )
#
# TypeError: extract_dataset() got an unexpected keyword argument 'dataset_path'

# %%
from audiofeatures import extract_dataset

df = extract_dataset(
    audio_folder="/Users/dhyan/Desktop/project/test data"
)

df.head()
# Out:
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# [INFO] Applying preprocessing
# [INFO] Splitting audio into windows
# [INFO] Extracting features
# [INFO] Feature extraction completed
# [INFO] Loading audio
# ...

# %%
df
# Out:
#       window  start_time  end_time       rms       zcr     energy  \
# 0          0         0.0       0.5  0.033188 -0.950295  12.143079
# 1          1         0.5       1.0  0.045797 -0.954014  23.123199
# 2          2         1.0       1.5  0.059783 -0.941043  39.403748
# 3          3         1.5       2.0  0.054512 -0.939501  32.761990
# 4          4         2.0       2.5  0.069843 -0.955918  53.780380
# ...      ...         ...       ...       ...       ...        ...
# 4169     694       347.0     347.5  0.036697 -0.926349  14.846848
# 4170     695       347.5     348.0  0.031623 -0.927256  11.025298
# 4171     696       348.0     348.5  0.028740 -0.912109   9.106710
# 4172     697       348.5     349.0  0.027913 -0.919274   8.589802
# 4173     698       349.0     349.5  0.026733 -0.925986   7.878810
#
#       peak_amplitude  crest_factor  dynamic_range  energy_variability  ...  \
# 0           0.119136      3.589781       0.227410            0.000226  ...
# ...
